# %% [markdown]
# ### 第十七章 潜在语义分解

# %%
import numpy as np

X = np.array([[2, 0, 0, 0],
             [0, 2, 0, 0],
             [2, 0, 1, 0],
             [0, 0, 2, 3],
             [0, 0, 0, 1],
             [1, 2, 2, 1]])

print(np.linalg.svd(X, full_matrices=False))
# Out:
# SVDResult(U=array([[-0.14082006,  0.51603569,  0.38610662,  0.54921822],
#        [-0.14937345,  0.21606629, -0.68729915,  0.43352752],
#        [-0.27964317,  0.5038812 ,  0.40741074, -0.25657299],
#        [-0.68022289, -0.57311192,  0.24639802,  0.09502542],
#        [-0.13419222, -0.18293431,  0.06792993,  0.56886928],
#        [-0.63162192,  0.26684084, -0.38370768, -0.33457651]]), S=array([4.57317186, 2.98998008, 2.49662441, 0.95550241]), Vh=array([[-0.32199717, -0.34155522, -0.63486195, -0.61368409],
#        [ 0.77146822,  0.32301695, -0.0363417 , -0.54696994],
#        [ 0.48198161, -0.85796392,  0.05318838,  0.16959551],
#        [ 0.26238967,  0.2071183 , -0.76993544,  0.54355597]]))
